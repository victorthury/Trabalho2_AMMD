# %%
import numpy as np
import pandas as pd
np.random.seed(42)

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

for i in [0,9,13]:
    si = plt.style.available[i]
    plt.style.use(si)

# %%
red_df = pd.read_csv('../data/wine_quality/winequality-red.csv', sep=';')
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
white_df = pd.read_csv('../data/wine_quality/winequality-white.csv', sep=';')
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
def to_name(i):
    l = [
        'one',
        'two',
        'three',
        'four',
        'five',
        'six',
        'seven',
        'eght',
        'nine', 
        'ten'
    ]
    return l[int(i)]

# %%
df = red_df.copy()
df.quality = df.quality.apply(to_name)

# %%
sns.pairplot(df, hue='quality')

# %% [markdown]
# ## Data Pre processing

# %%
def values2zscores(df):
    zdf = df.copy()
    for cname in df:
        mean, std = df[cname].mean(), df[cname].std()
        zdf[cname] = (df[cname] - mean)/std
        
    return zdf

def normalize(df):
    ndf = df.copy()
    for cname in df:
        maxv, minv = df[cname].max(), df[cname].min()
        ndf[cname] = (df[cname] - minv)/(maxv-minv)
        
    return ndf

# %%
red_y = red_df.quality
red_x = red_df.drop(columns=['quality'])

white_y = white_df.quality
white_x = white_df.drop(columns=['quality'])

# %%
# for regression
red_ny = red_y / 10
white_ny = white_y / 10

# %% [markdown]
# ### Zsocore

# %%
red_z = values2zscores(red_x)
red_z.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528194          0.961576    -1.391037       -0.453077  -0.243630
# 1      -0.298454          1.966827    -1.391037        0.043403   0.223805
# 2      -0.298454          1.296660    -1.185699       -0.169374   0.096323
# 3       1.654339         -1.384011     1.483689       -0.453077  -0.264878
# 4      -0.528194          0.961576    -1.391037       -0.453077  -0.243630
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466047             -0.379014  0.558100  1.288240  -0.579025
# 1             0.872365              0.624168  0.028252 -0.719708   0.128910
# 2            -0.083643              0.228975  0.134222 -0.331073  -0.048074
# 3             0.107558              0.411372  0.664069 -0.978798  -0.461036
# 4            -0.466047             -0.379014  0.558100  1.288240  -0.579025
#
#     alcohol
# 0 -0.959946
# 1 -0.584594
# 2 -0.584594
# 3 -0.584594
# 4 -0.959946

# %%
white_z = values2zscores(white_x)
white_z.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.172079         -0.081762     0.213258        2.821061  -0.035351
# 1      -0.657434          0.215874     0.047996       -0.944669   0.147732
# 2       1.475600          0.017450     0.543783        0.100272   0.193503
# 3       0.409083         -0.478608    -0.117266        0.415726   0.559670
# 4       0.409083         -0.478608    -0.117266        0.415726   0.559670
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.569873              0.744489  2.331274 -1.246794  -0.349149
# 1            -1.252891             -0.149669 -0.009153  0.739953   0.001342
# 2            -0.312109             -0.973236  0.358628  0.475053  -0.436771
# 3             0.687471              1.120977  0.525802  0.011479  -0.787262
# 4             0.687471              1.120977  0.525802  0.011479  -0.787262
#
#     alcohol
# 0 -1.393010
# 1 -0.824192
# 2 -0.336633
# 3 -0.499152
# 4 -0.499152

# %% [markdown]
# ## Visualize

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
rpc = pca.fit_transform(red_z)

# %%
pca = PCA(n_components=2)
wpc = pca.fit_transform(white_z)

# %%
plt.scatter(wpc.T[0], wpc.T[1])
plt.scatter(rpc.T[0], rpc.T[1])

plt.show()

# %%
plt.scatter(wpc.T[0], white_ny)
plt.scatter(rpc.T[0], red_ny)

plt.show()

# %% [markdown]
# ## Try some Classification Models

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
# Out:
# /usr/lib/python3/dist-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
rdf = RandomForestClassifier()
csvm_lin = svm.SVC(kernel='linear', C=1)
csvm_rbf = svm.SVC(kernel='rbf', C=1)
gnb = GaussianNB()

models = [
    ('Random Forest', rdf), 
    ('Linar SVM', csvm_lin),
    ('RBF SVM', csvm_rbf),
    ('GaussianNB', gnb)
]

# %%
print('Zscore\n')

for mname, model in models:
    red_c = cross_val_score(model, red_z, red_y, cv=5)
    white_c = cross_val_score(model, white_z, white_y, cv=5)
    print(f'{mname}:')
    print(f'\t[tred whine]  {np.mean(red_c)}\n\t[white whine] {np.mean(white_c)}')
#     print(f'\t{red_c, white_c}\n')
# Out:
# Zscore
#
# Random Forest:
# 	[tred whine]  0.5329579006224285
# 	[white whine] 0.4936899194116025
# Linar SVM:
# 	[tred whine]  0.5574097938088675
# 	[white whine] 0.5108405159403399
# RBF SVM:
# 	[tred whine]  0.5854377213016544
# 	[white whine] 0.5298247151621385
# GaussianNB:
# 	[tred whine]  0.5229281218433124
# 	[white whine] 0.43036759657991636

# %% [markdown]
# # Feature  Eng

# %%
red_df.quality.plot.hist()

# %%
def to_bin(i):
    l = [
        'one',
        'two',
        'three',
        'four',
        'five',
        'six',
        'seven',
        'eght',
        'nine', 
        'ten'
    ]
    return "good" if int(i)>6.5 else "bad"

df = red_df.copy()
df.quality = df.quality.apply(to_bin)

sns.pairplot(df, hue='quality')
